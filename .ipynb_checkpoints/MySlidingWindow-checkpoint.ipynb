# %%
import numpy as np
import librosa
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.fftpack import dct

sns.set()
import os
import scipy
import librosa.display
from IPython.display import Audio
import random
from functools import reduce
from sklearn.mixture import GaussianMixture
import sklearn
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
# sample_rate = 48000
# Given .wav file, extract MFCC features with default 
def extractMFCC(filename, sample_rate, mels, nmfccs):
    #sample_rate = 192000
    utter_part, sr = librosa.core.load(filename, sample_rate)  # load utterance audio
    # intervals = librosa.effects.split(utter_part, top_db=30)  # voice activity detection
    # print(intervals)
    S_total = []

    S = librosa.core.stft(y=utter_part)
    S = np.abs(S) ** 2
    # print("Size of S is {}".format(S.shape))
    mel_basis = librosa.filters.mel(sr=sample_rate, n_fft=2048, n_mels=mels)
    S = np.log10(np.dot(mel_basis, S) + 1e-6)

    # plt.show()
    # plt.pause(2)
    # Extract MFCC feature
    # mfccs = librosa.feature.mfcc(y=utter_part.astype('float'), sr=sample_rate, n_mfcc=10)
    # S_total = np.concatenate(S_total,axis=1)
    # print(S_total.shape)
    mfccs = librosa.feature.mfcc(S = S, sr=sample_rate, n_mfcc=nmfccs) # (128, times)
    # print(mfccs.shape)
    print("Shape of mfcc features is {}".format(mfccs.shape))
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(mfccs, x_axis='frames', hop_length=58)
    plt.colorbar()
    plt.title('MFCC')
    plt.tight_layout()
    mfccs = mfccs.reshape(-1,10)
    return mfccs

# %%
dataset = [dirs for dirs in os.listdir('.') if(dirs[-4:]==("high"))]
dataset
# Out:
# ['hanqing-high', 'jianzhi-high', 'liuli-high', 'Nick-high', 'xiao-high']

# %%
fricative_path = os.path.join('.', dataset[0],'1.wav')

# %%
mfcc1 = extractMFCC(fricative_path,192000,mels=10, nmfccs=10)
# Out:
# Shape of mfcc features is (10, 752)

# %%
fricative_path = os.path.join('.', dataset[0],'2.wav')
mfcc2 = extractMFCC(fricative_path,192000,mels=10, nmfccs=10)
# Out:
# Shape of mfcc features is (10, 752)

# %%
fricative_path = os.path.join('.', dataset[0],'3.wav')
mfcc3 = extractMFCC(fricative_path,192000,mels=10, nmfccs=10)
# Out:
# Shape of mfcc features is (10, 752)

# %%
fricative_path = os.path.join('.', dataset[0],'4.wav')
mfcc4 = extractMFCC(fricative_path,192000,mels=10, nmfccs=10)
# Out:
# Shape of mfcc features is (10, 752)

# %%
mfcc2.shape
fricative = mfcc2[0:200,:]
fricative = fricative.reshape(10,-1)
print(fricative.shape)
librosa.display.specshow(fricative, x_axis='time',hop_length=100)
# Out:
# (10, 200)

# %%
X = mfcc2
Y = mfcc3
print(mfcc2.shape)
sim = cosine_similarity(X, Y, dense_output=True)
print(sim.shape)
fricative = mfcc2[200:220,:]
print(fricative.shape)
# Out:
# (752, 10)
# (752, 752)
# (20, 10)

# %%
752/20
# Out:
# 37.6

# %%
fricative = fricative.reshape(-1,200)
sumv = 0
for i in range(round(752/20)-1):
    selected = mfcc3[i*20:(i+1)*20, :]
    selected = selected.reshape(-1,200)
    # print(selected.shape)
    sim = cosine_similarity(fricative, selected, dense_output=True)
    sumv = sumv + sim[0][0]
    if(sim[0][0] > 0.95):
        print(i, i*20, sim)
print(sumv)
# Out:
# 9 180 [[0.9585309]]
# 10 200 [[0.95084643]]
# 17 340 [[0.9853279]]
# 21.90782994031906

# %%
sumv = 0
for i in range(round(752/20)-1):
    selected = mfcc4[i*20:(i+1)*20, :]
    selected = selected.reshape(-1,200)
    # print(selected.shape)
    sim = cosine_similarity(fricative, selected, dense_output=True)
    if(sim[0][0] > 0.95):
        print(i, i*20, sim)
    sumv = sumv + sim[0][0]
    #print(i, i*20, sim)
print(sumv)
# Out:
# 14 280 [[0.97549397]]
# 18 360 [[0.96177775]]
# 19.79231222718954

# %%
fricative_path = os.path.join('.', dataset[1],'2.wav')
jianzhi_mfcc1 = extractMFCC(fricative_path,192000,mels=10, nmfccs=10)
# Out:
# Shape of mfcc features is (10, 752)

# %%
sumv = 0
for i in range(round(752/20)-1):
    selected = jianzhi_mfcc1[i*20:(i+1)*20, :]
    selected = selected.reshape(-1,200)
    # print(selected.shape)
    sim = cosine_similarity(fricative, selected, dense_output=True)
    if(sim[0][0] > 0.95):
        print(i, i*20, sim)
    sumv = sumv + sim[0][0]
    #print(i, i*20, sim)
print(sumv)
# Out:
# 10 200 [[0.96585566]]
# 21.45435430854559

# %%
fricative_path = os.path.join('.', dataset[1],'1.wav')
jianzhi_mfcc1 = extractMFCC(fricative_path,192000,mels=10, nmfccs=10)
sumv = 0
for i in range(round(752/20)-1):
    selected = jianzhi_mfcc1[i*20:(i+1)*20, :]
    selected = selected.reshape(-1,200)
    # print(selected.shape)
    sim = cosine_similarity(fricative, selected, dense_output=True)
    if(sim[0][0] > 0.95):
        print(i, i*20, sim)
    sumv = sumv + sim[0][0]
print(sumv)
# Out:
# Shape of mfcc features is (10, 752)
# 0 0 [[-0.96037185]]
# 1 20 [[-0.94812226]]
# 2 40 [[-0.9112738]]
# 3 60 [[-0.83670706]]
# 4 80 [[0.95072806]]
# 5 100 [[0.7913806]]
# 6 120 [[0.8146894]]
# 7 140 [[0.92536324]]
# 8 160 [[0.9573874]]
# 9 180 [[0.91828185]]
# 10 200 [[0.957507]]
# 11 220 [[0.8203529]]
# 12 240 [[0.9169274]]
# 13 260 [[0.41687128]]
# 14 280 [[0.87746716]]
# 15 300 [[0.93250084]]
# 16 320 [[0.8403186]]
# 17 340 [[0.7162171]]
# 18 360 [[0.8366107]]
# 19 380 [[0.9042625]]
# 20 400 [[0.46861342]]
# 21 420 [[0.87495154]]
# 22 440 [[0.6162892]]
# 23 460 [[0.11528209]]
# 24 480 [[-0.815909]]
# 25 500 [[-0.13485254]]
# 26 520 [[0.8166508]]
# 27 540 [[0.9091452]]
# 28 560 [[-0.516231]]
# 29 580 [[0.8939339]]
# 30 600 [[-0.03736163]]
# 31 620 [[0.15996131]]
# 32 640 [[0.09820154]]
# 33 660 [[0.27824074]]
# 34 680 [[0.20682727]]
# 35 700 [[0.60502344]]
# 36 720 [[0.5932338]]
# 15.052391096949577

# %%
fricative_path = os.path.join('.', dataset[1],'3.wav')
jianzhi_mfcc1 = extractMFCC(fricative_path,192000,mels=10, nmfccs=10)
sumv = 0
for i in range(round(752/20)-1):
    selected = jianzhi_mfcc1[i*20:(i+1)*20, :]
    selected = selected.reshape(-1,200)
    # print(selected.shape)
    sim = cosine_similarity(fricative, selected, dense_output=True)
    sumv = sumv + sim[0][0]
    print(i, i*20, sim)
print(sumv)
# Out:
# Shape of mfcc features is (10, 752)
# 0 0 [[-0.90882826]]
# 1 20 [[-0.91783506]]
# 2 40 [[-0.962234]]
# 3 60 [[-0.8332333]]
# 4 80 [[0.8548353]]
# 5 100 [[0.7303844]]
# 6 120 [[0.93480164]]
# 7 140 [[0.90695363]]
# 8 160 [[0.5768543]]
# 9 180 [[0.9764752]]
# 10 200 [[0.95919967]]
# 11 220 [[0.782346]]
# 12 240 [[0.1352053]]
# 13 260 [[0.94567186]]
# 14 280 [[0.90054786]]
# 15 300 [[0.4489208]]
# 16 320 [[0.26437208]]
# 17 340 [[0.9468239]]
# 18 360 [[0.86588645]]
# 19 380 [[0.47335708]]
# 20 400 [[0.7662007]]
# 21 420 [[0.90585357]]
# 22 440 [[0.73887897]]
# 23 460 [[0.13552165]]
# 24 480 [[0.40182197]]
# 25 500 [[0.5900285]]
# 26 520 [[0.76650405]]
# 27 540 [[0.8475725]]
# 28 560 [[0.8391547]]
# 29 580 [[0.93661064]]
# 30 600 [[0.5005396]]
# 31 620 [[0.69467014]]
# 32 640 [[0.19672267]]
# 33 660 [[0.7330668]]
# 34 680 [[0.7634259]]
# 35 700 [[-0.23018211]]
# 36 720 [[0.04759205]]
# 17.714487124234438

# %%
fricative_path = os.path.join('.', dataset[1],'4.wav')
jianzhi_mfcc1 = extractMFCC(fricative_path,192000,mels=10, nmfccs=10)
sumv = 0
for i in range(round(752/20)-1):
    selected = jianzhi_mfcc1[i*20:(i+1)*20, :]
    selected = selected.reshape(-1,200)
    # print(selected.shape)
    sim = cosine_similarity(fricative, selected, dense_output=True)
    sumv = sumv + sim[0][0]
    print(i, i*20, sim)
print(sumv)
# Out:
# Shape of mfcc features is (10, 752)
# 0 0 [[-0.89459574]]
# 1 20 [[-0.93222445]]
# 2 40 [[-0.96050173]]
# 3 60 [[-0.831693]]
# 4 80 [[0.92082095]]
# 5 100 [[0.7411349]]
# 6 120 [[0.94350296]]
# 7 140 [[0.89303064]]
# 8 160 [[0.8606732]]
# 9 180 [[0.9150593]]
# 10 200 [[0.95926017]]
# 11 220 [[0.8429956]]
# 12 240 [[0.7302749]]
# 13 260 [[0.9029504]]
# 14 280 [[0.9200308]]
# 15 300 [[0.7632113]]
# 16 320 [[0.6776348]]
# 17 340 [[0.89899635]]
# 18 360 [[0.8505189]]
# 19 380 [[0.2135116]]
# 20 400 [[0.663211]]
# 21 420 [[0.8797071]]
# 22 440 [[0.44303545]]
# 23 460 [[-0.26081154]]
# 24 480 [[-0.53046435]]
# 25 500 [[0.50031054]]
# 26 520 [[0.45309654]]
# 27 540 [[0.36387774]]
# 28 560 [[0.8590572]]
# 29 580 [[0.9339742]]
# 30 600 [[0.35959676]]
# 31 620 [[-0.03144749]]
# 32 640 [[0.6582848]]
# 33 660 [[0.84505534]]
# 34 680 [[0.06196569]]
# 35 700 [[-0.12853272]]
# 36 720 [[0.2956192]]
# 15.780127219855785

# %%
fricative_path = os.path.join('.', dataset[1],'5.wav')
jianzhi_mfcc1 = extractMFCC(fricative_path,192000,mels=10, nmfccs=10)
sumv = 0
for i in range(round(752/20)-1):
    selected = jianzhi_mfcc1[i*20:(i+1)*20, :]
    selected = selected.reshape(-1,200)
    # print(selected.shape)
    sim = cosine_similarity(fricative, selected, dense_output=True)
    sumv = sumv + sim[0][0]
    print(i, i*20, sim)
print(sumv)
# Out:
# Shape of mfcc features is (10, 752)
# 0 0 [[-0.9166123]]
# 1 20 [[-0.91320485]]
# 2 40 [[-0.9617769]]
# 3 60 [[-0.8258008]]
# 4 80 [[0.882539]]
# 5 100 [[0.8218348]]
# 6 120 [[0.9553195]]
# 7 140 [[0.9468162]]
# 8 160 [[0.7798653]]
# 9 180 [[0.923234]]
# 10 200 [[0.96114165]]
# 11 220 [[0.7666611]]
# 12 240 [[0.9006932]]
# 13 260 [[0.9273254]]
# 14 280 [[0.96808153]]
# 15 300 [[0.62682515]]
# 16 320 [[0.6628275]]
# 17 340 [[0.91666716]]
# 18 360 [[0.897263]]
# 19 380 [[0.61786157]]
# 20 400 [[0.6421829]]
# 21 420 [[0.8939473]]
# 22 440 [[0.6725855]]
# 23 460 [[-0.48827899]]
# 24 480 [[-0.40722615]]
# 25 500 [[0.6475304]]
# 26 520 [[0.8225719]]
# 27 540 [[0.5335299]]
# 28 560 [[0.67728084]]
# 29 580 [[0.96294487]]
# 30 600 [[0.74000293]]
# 31 620 [[0.270061]]
# 32 640 [[0.28333622]]
# 33 660 [[0.8131597]]
# 34 680 [[0.7462752]]
# 35 700 [[0.22482255]]
# 36 720 [[0.35246998]]
# 18.324757158756256

# %%
fricative_path = os.path.join('.', dataset[1],'6.wav')
jianzhi_mfcc1 = extractMFCC(fricative_path,192000,mels=10, nmfccs=10)
sumv = 0
for i in range(round(752/20)-1):
    selected = jianzhi_mfcc1[i*20:(i+1)*20, :]
    selected = selected.reshape(-1,200)
    # print(selected.shape)
    sim = cosine_similarity(fricative, selected, dense_output=True)
    sumv = sumv + sim[0][0]
    print(i, i*20, sim)
print(sumv)
# Out:
# Shape of mfcc features is (10, 752)
# 0 0 [[-0.8898093]]
# 1 20 [[-0.89476055]]
# 2 40 [[-0.96152765]]
# 3 60 [[-0.8210592]]
# 4 80 [[0.94169563]]
# 5 100 [[0.84674525]]
# 6 120 [[0.94666046]]
# 7 140 [[0.93959844]]
# 8 160 [[0.70903563]]
# 9 180 [[0.8956898]]
# 10 200 [[0.96585566]]
# 11 220 [[0.6138157]]
# 12 240 [[0.6158918]]
# 13 260 [[0.949966]]
# 14 280 [[0.9238572]]
# 15 300 [[0.46797755]]
# 16 320 [[0.6873701]]
# 17 340 [[0.94521576]]
# 18 360 [[0.89222497]]
# 19 380 [[0.76960933]]
# 20 400 [[0.64171576]]
# 21 420 [[0.88342726]]
# 22 440 [[0.7266942]]
# 23 460 [[0.11298036]]
# 24 480 [[0.23198801]]
# 25 500 [[0.6951783]]
# 26 520 [[0.7591161]]
# 27 540 [[0.55575734]]
# 28 560 [[0.9306383]]
# 29 580 [[0.94343954]]
# 30 600 [[0.7342156]]
# 31 620 [[0.7828975]]
# 32 640 [[0.8391556]]
# 33 660 [[0.755202]]
# 34 680 [[0.8911114]]
# 35 700 [[0.74488914]]
# 36 720 [[0.68189526]]
# 21.45435430854559
